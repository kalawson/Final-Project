# %% [markdown]
# To start, we need to import the modules we'll need later and provide a valid email address to use with Entrez.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from Bio import Entrez
import csv
from collections import defaultdict

# %%
#Register with Entrez
Entrez.email = 'kalawson@vassar.edu'

# %% [markdown]
# Next, we decide what we want to search for and open an API to access PubMed data, using ESearch to allow us to retrieve full records from PubMed.  Below, define the keyword you want to search for.  It should be formatted 'like+this'.  A search term for alcohol addiction has been given as an example.  You can also search in a specific area, like in the title, list of authors ('AuthorList'), or journal in which the article was published ('FullJournalName') and specify the range of years you're interested in.

# %%
#Define keyword, area, and range of years that you want to search on PubMed
keyword = 'alcoholism'
area = 'Title'
start_year_range = '2005'
end_year_range = '2015'

# %%
#Use eSearch to return PMIDs about your topic

# %%
handle = Entrez.esearch(db='pubmed', term=keyword, field = area, retmode='xml', idtype='acc', mindate=start_year_range, maxdate=end_year_range)
data = Entrez.read(handle)

# %% [markdown]
# ESearch gives us a lot of information, but it's in the form of ID numbers, not titles, authors, or any other relevant information.  To make it easier to read, we'll use ESummary to search PubMed using the ID numbers we got from ESearch.

# %%
#Use eSummary to convert PMIDs to useful information
UID = data['IdList']
print(UID)
# Out:
# ['26706806', '26704671', '26672247', '26661206', '26640531', '26626033', '26589585', '26580209', '26578987', '26578046', '26559000', '26537217', '26529024', '26502590', '26475672', '26455281', '26452454', '26437315', '26426670', '26418276']

# %%
attributes_list = []

for ID in range(len(UID)):
    record = Entrez.esummary(db='pubmed', id=UID[ID])
    attributes_list.append(Entrez.read(record))

# %%
for attributes in attributes_list:
    for information in attributes:
        for key1, value1 in information.items():
            print(key1, value1)
# Out:
# Item []
# Id 26706806
# PubDate 2015 Dec 15
# EPubDate 2015 Dec 15
# Source Adicciones
# AuthorList ['Pascual Pastor F']
# LastAuthor Pascual Pastor F
# Title Alcoholism and mutual help. From necessity to evidence.
# Volume 27
# Issue 4
# Pages 243-5
# LangList ['English', 'Spanish']
# NlmUniqueID 9605506
# ISSN 0214-4840
# ESSN
# PubTypeList ['Editorial']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26706806'], 'medline': [], 'rid': '26706806', 'eid': '26706806'}
# History {'pubmed': ['2015/12/27 06:00'], 'medline': ['2017/08/24 06:00'], 'entrez': '2015/12/27 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Adicciones
# ELocationID
# SO 2015 Dec 15;27(4):243-5
# Item []
# Id 26704671
# PubDate 2015 Dec
# EPubDate
# Source Alcohol
# AuthorList ['Roberto M', 'Varodayan F']
# LastAuthor Varodayan F
# Title Commentary on the Third International Congress on "Alcoholism and Stress: A Framework for Future Treatment Strategies".
# Volume 49
# Issue 8
# Pages e1-2
# LangList ['English']
# NlmUniqueID 8502311
# ISSN 0741-8329
# ESSN 1873-6823
# PubTypeList ['Editorial']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26704671'], 'medline': [], 'pii': 'S0741-8329(15)30128-2', 'doi': '10.1016/j.alcohol.2015.11.007', 'rid': '26704671', 'eid': '26704671'}
# DOI 10.1016/j.alcohol.2015.11.007
# History {'pubmed': ['2015/12/26 06:00'], 'medline': ['2016/09/28 06:00'], 'received': '2015/11/02 00:00', 'accepted': '2015/11/02 00:00', 'entrez': '2015/12/26 06:00'}
# References []
# HasAbstract 0
# PmcRefCount 0
# FullJournalName Alcohol (Fayetteville, N.Y.)
# ELocationID doi: 10.1016/j.alcohol.2015.11.007
# SO 2015 Dec;49(8):e1-2
# Item []
# Id 26672247
# PubDate 2015 Jul
# EPubDate
# Source Lin Chung Er Bi Yan Hou Tou Jing Wai Ke Za Zhi
# AuthorList ['Feng J', 'Liu H']
# LastAuthor Liu H
# Title [The expression and significance of VIP and its receptor in the cochlea of different degrees of chronic alcoholism rats].
# Volume 29
# Issue 14
# Pages 1295-8
# LangList ['Chinese']
# NlmUniqueID 101303164
# ISSN 1001-1781
# ESSN
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26672247'], 'medline': [], 'rid': '26672247', 'eid': '26672247'}
# History {'pubmed': ['2015/12/18 06:00'], 'medline': ['2016/06/17 06:00'], 'entrez': '2015/12/18 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Lin chuang er bi yan hou tou jing wai ke za zhi = Journal of clinical otorhinolaryngology, head, and neck surgery
# ELocationID
# SO 2015 Jul;29(14):1295-8
# Item []
# Id 26661206
# PubDate 2016 Sep
# EPubDate 2015 Oct 14
# Source J Cereb Blood Flow Metab
# AuthorList ['Ritz L', 'Segobin S', 'Lannuzel C', 'Boudehent C', 'Vabret F', 'Eustache F', 'Beaunieux H', 'Pitel AL']
# LastAuthor Pitel AL
# Title Direct voxel-based comparisons between grey matter shrinkage and glucose hypometabolism in chronic alcoholism.
# Volume 36
# Issue 9
# Pages 1625-40
# LangList ['English']
# NlmUniqueID 8112566
# ISSN 0271-678X
# ESSN 1559-7016
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26661206'], 'medline': [], 'pii': '0271678X15611136', 'doi': '10.1177/0271678X15611136', 'pmc': 'PMC5012518', 'rid': '26661206', 'eid': '26661206', 'pmcid': 'pmc-id: PMC5012518;'}
# DOI 10.1177/0271678X15611136
# History {'pubmed': ['2015/12/15 06:00'], 'medline': ['2017/08/05 06:00'], 'received': '2015/01/07 00:00', 'accepted': '2015/07/08 00:00', 'entrez': '2015/12/15 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 4
# FullJournalName Journal of cerebral blood flow and metabolism : official journal of the International Society of Cerebral Blood Flow and Metabolism
# ELocationID doi: 10.1177/0271678X15611136
# SO 2016 Sep;36(9):1625-40
# Item []
# Id 26640531
# PubDate 2015 Nov
# EPubDate 2015 Sep 23
# Source Exp Ther Med
# AuthorList ['Li S', 'Wang SU', 'Guo ZG', 'Huang N', 'Zhao FR', 'Zhu ML', 'Ma LJ', 'Liang JY', 'Zhang YL', 'Huang ZL', 'Wan GR']
# LastAuthor Wan GR
# Title Protective effect of Xingnaojia formulation on rats with brain and liver damage caused by chronic alcoholism.
# Volume 10
# Issue 5
# Pages 1643-1652
# LangList ['English']
# NlmUniqueID 101531947
# ISSN 1792-0981
# ESSN 1792-1015
# PubTypeList ['Journal Article']
# RecordStatus PubMed
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26640531'], 'medline': [], 'doi': '10.3892/etm.2015.2773', 'pii': 'ETM-0-0-2773', 'pmc': 'PMC4665616', 'rid': '26640531', 'eid': '26640531', 'pmcid': 'pmc-id: PMC4665616;'}
# DOI 10.3892/etm.2015.2773
# History {'pubmed': ['2015/12/08 06:00'], 'medline': ['2015/12/08 06:00'], 'received': '2014/05/15 00:00', 'accepted': '2015/07/31 00:00', 'entrez': '2015/12/08 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Experimental and therapeutic medicine
# ELocationID
# SO 2015 Nov;10(5):1643-1652
# Item []
# Id 26626033
# PubDate 2015 Nov-Dec
# EPubDate
# Source Gastroenterol Nurs
# AuthorList ['Zhou M', 'Wagner LM', 'Diflo T', 'Naegle M']
# LastAuthor Naegle M
# Title Implementation of the High-Risk Alcoholism Relapse Scale in a Liver Transplant Clinic.
# Volume 38
# Issue 6
# Pages 447-54
# LangList ['English']
# NlmUniqueID 8915377
# ISSN 1042-895X
# ESSN 1538-9766
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26626033'], 'medline': [], 'doi': '10.1097/SGA.0000000000000168', 'pii': '00001610-201511000-00006', 'rid': '26626033', 'eid': '26626033'}
# DOI 10.1097/SGA.0000000000000168
# History {'pubmed': ['2015/12/03 06:00'], 'medline': ['2017/02/22 06:00'], 'entrez': '2015/12/03 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Gastroenterology nursing : the official journal of the Society of Gastroenterology Nurses and Associates
# ELocationID doi: 10.1097/SGA.0000000000000168
# SO 2015 Nov-Dec;38(6):447-54
# Item []
# Id 26589585
# PubDate 2016 Jan
# EPubDate 2015 Nov 19
# Source Alcohol Alcohol
# AuthorList ['Sharma B', 'Dabur R']
# LastAuthor Dabur R
# Title Protective Effects of Tinospora cordifolia on Hepatic and Gastrointestinal Toxicity Induced by Chronic and Moderate Alcoholism.
# Volume 51
# Issue 1
# Pages 1-10
# LangList ['English']
# NlmUniqueID 8310684
# ISSN 0735-0414
# ESSN 1464-3502
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26589585'], 'medline': [], 'pii': 'agv130', 'doi': '10.1093/alcalc/agv130', 'rid': '26589585', 'eid': '26589585'}
# DOI 10.1093/alcalc/agv130
# History {'pubmed': ['2015/11/22 06:00'], 'medline': ['2016/09/20 06:00'], 'received': '2015/07/11 00:00', 'accepted': '2015/10/26 00:00', 'entrez': '2015/11/22 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Alcohol and alcoholism (Oxford, Oxfordshire)
# ELocationID doi: 10.1093/alcalc/agv130
# SO 2016 Jan;51(1):1-10
# Item []
# Id 26580209
# PubDate 2015
# EPubDate 2015 Nov 18
# Source PLoS One
# AuthorList ['Kamarajan C', 'Pandey AK', 'Chorlian DB', 'Manz N', 'Stimus AT', 'Anokhin AP', 'Bauer LO', 'Kuperman S', 'Kramer J', 'Bucholz KK', 'Schuckit MA', 'Hesselbrock VM', 'Porjesz B']
# LastAuthor Porjesz B
# Title Deficient Event-Related Theta Oscillations in Individuals at Risk for Alcoholism: A Study of Reward Processing and Impulsivity Features.
# Volume 10
# Issue 11
# Pages e0142659
# LangList ['English']
# NlmUniqueID 101285081
# ISSN
# ESSN 1932-6203
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus
# ArticleIds {'pubmed': ['26580209'], 'medline': [], 'doi': '10.1371/journal.pone.0142659', 'pii': 'PONE-D-15-27019', 'pmc': 'PMC4651365', 'rid': '26580209', 'eid': '26580209', 'pmcid': 'pmc-id: PMC4651365;'}
# DOI 10.1371/journal.pone.0142659
# History {'pubmed': ['2015/11/19 06:00'], 'medline': ['2016/06/18 06:00'], 'received': '2015/06/23 00:00', 'accepted': '2015/10/26 00:00', 'entrez': '2015/11/19 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 5
# FullJournalName PloS one
# ELocationID doi: 10.1371/journal.pone.0142659
# SO 2015;10(11):e0142659
# Item []
# Id 26578987
# PubDate 2015
# EPubDate 2015 Nov 2
# Source Front Psychiatry
# AuthorList ['Cheng DT', 'Jacobson SW', 'Jacobson JL', 'Molteno CD', 'Stanton ME', 'Desmond JE']
# LastAuthor Desmond JE
# Title Eyeblink Classical Conditioning in Alcoholism and Fetal Alcohol Spectrum Disorders.
# Volume 6
# Issue
# Pages 155
# LangList ['English']
# NlmUniqueID 101545006
# ISSN
# ESSN 1664-0640
# PubTypeList ['Journal Article', 'Review']
# RecordStatus PubMed
# PubStatus
# ArticleIds {'pubmed': ['26578987'], 'medline': [], 'doi': '10.3389/fpsyt.2015.00155', 'pmc': 'PMC4629452', 'rid': '26578987', 'eid': '26578987', 'pmcid': 'pmc-id: PMC4629452;'}
# DOI 10.3389/fpsyt.2015.00155
# History {'pubmed': ['2015/11/19 06:00'], 'medline': ['2015/11/19 06:01'], 'received': '2015/07/09 00:00', 'accepted': '2015/10/16 00:00', 'entrez': '2015/11/19 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 4
# FullJournalName Frontiers in psychiatry
# ELocationID doi: 10.3389/fpsyt.2015.00155
# SO 2015;6:155
# Item []
# Id 26578046
# PubDate 2015 May
# EPubDate
# Source Tunis Med
# AuthorList ['Nakhli J', 'Gorsane MA', 'Bouhlel S', 'Lahmar I', 'El Kissi Y', 'Ben Nasr S', 'Ben Hadj Ali B']
# LastAuthor Ben Hadj Ali B
# Title [Prevalence of alcoholism in primary care in the governorate of Sousse].
# Volume 93
# Issue 5
# Pages 297-301
# LangList ['French']
# NlmUniqueID 0413766
# ISSN 0041-4131
# ESSN
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26578046'], 'medline': [], 'pii': '/article-medicale-tunisie.php?article=2809', 'rid': '26578046', 'eid': '26578046'}
# History {'pubmed': ['2015/11/19 06:00'], 'medline': ['2016/06/10 06:00'], 'entrez': '2015/11/19 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName La Tunisie medicale
# ELocationID
# SO 2015 May;93(5):297-301
# Item []
# Id 26559000
# PubDate 2016 Jan 1
# EPubDate 2015 Oct 21
# Source Drug Alcohol Depend
# AuthorList ['Cservenka A']
# LastAuthor Cservenka A
# Title Neurobiological phenotypes associated with a family history of alcoholism.
# Volume 158
# Issue
# Pages 8-21
# LangList ['English']
# NlmUniqueID 7513587
# ISSN 0376-8716
# ESSN 1879-0046
# PubTypeList ['Journal Article', 'Review']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26559000'], 'medline': [], 'pii': 'S0376-8716(15)01717-2', 'doi': '10.1016/j.drugalcdep.2015.10.021', 'pmc': 'PMC4698007', 'mid': 'NIHMS732466', 'rid': '26559000', 'eid': '26559000', 'pmcid': 'pmc-id: PMC4698007;manuscript-id: NIHMS732466;'}
# DOI 10.1016/j.drugalcdep.2015.10.021
# History {'pubmed': ['2015/11/13 06:00'], 'medline': ['2016/08/19 06:00'], 'received': '2015/06/09 00:00', 'revised': '2015/10/06 00:00', 'accepted': '2015/10/11 00:00', 'entrez': '2015/11/13 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 27
# FullJournalName Drug and alcohol dependence
# ELocationID doi: 10.1016/j.drugalcdep.2015.10.021
# SO 2016 Jan 1;158:8-21
# Item []
# Id 26537217
# PubDate 2017 Mar
# EPubDate 2015 Nov 5
# Source Addict Biol
# AuthorList ['Blaine SK', 'Seo D', 'Sinha R']
# LastAuthor Sinha R
# Title Peripheral and prefrontal stress system markers and risk of relapse in alcoholism.
# Volume 22
# Issue 2
# Pages 468-478
# LangList ['English']
# NlmUniqueID 9604935
# ISSN 1355-6215
# ESSN 1369-1600
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26537217'], 'medline': [], 'doi': '10.1111/adb.12320', 'pmc': 'PMC4860170', 'mid': 'NIHMS736400', 'rid': '26537217', 'eid': '26537217', 'pmcid': 'pmc-id: PMC4860170;manuscript-id: NIHMS736400;'}
# DOI 10.1111/adb.12320
# History {'pubmed': ['2015/11/06 06:00'], 'medline': ['2018/01/31 06:00'], 'received': '2015/04/27 00:00', 'revised': '2015/08/31 00:00', 'accepted': '2015/09/17 00:00', 'entrez': '2015/11/06 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 10
# FullJournalName Addiction biology
# ELocationID doi: 10.1111/adb.12320
# SO 2017 Mar;22(2):468-478
# Item []
# Id 26529024
# PubDate 2015 Oct 29
# EPubDate 2015 Oct 29
# Source Behav Sci (Basel)
# AuthorList ['Choate PW']
# LastAuthor Choate PW
# Title Adolescent Alcoholism and Drug Addiction: The Experience of Parents.
# Volume 5
# Issue 4
# Pages 461-76
# LangList ['English']
# NlmUniqueID 101576826
# ISSN
# ESSN 2076-328X
# PubTypeList ['Journal Article']
# RecordStatus PubMed
# PubStatus epublish
# ArticleIds {'pubmed': ['26529024'], 'medline': [], 'pii': 'bs5040461', 'doi': '10.3390/bs5040461', 'pmc': 'PMC4695773', 'rid': '26529024', 'eid': '26529024', 'pmcid': 'pmc-id: PMC4695773;'}
# DOI 10.3390/bs5040461
# History {'pubmed': ['2015/11/04 06:00'], 'medline': ['2015/11/04 06:01'], 'received': '2015/06/10 00:00', 'revised': '2015/10/25 00:00', 'accepted': '2015/10/26 00:00', 'entrez': '2015/11/04 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Behavioral sciences (Basel, Switzerland)
# ELocationID doi: 10.3390/bs5040461
# SO 2015 Oct 29;5(4):461-76
# Item []
# Id 26502590
# PubDate 2015 Aug 26
# EPubDate
# Source Rev Med Suisse
# AuthorList ['Nau JY']
# LastAuthor Nau JY
# Title [August 2015: miscellanea on malaria, alcoholism and road accidents].
# Volume 11
# Issue 483
# Pages 1572-3
# LangList ['French']
# NlmUniqueID 101219148
# ISSN 1660-9379
# ESSN
# PubTypeList ['News']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26502590'], 'medline': [], 'rid': '26502590', 'eid': '26502590'}
# History {'pubmed': ['2015/10/28 06:00'], 'medline': ['2016/01/06 06:00'], 'entrez': '2015/10/28 06:00'}
# References []
# HasAbstract 0
# PmcRefCount 0
# FullJournalName Revue medicale suisse
# ELocationID
# SO 2015 Aug 26;11(483):1572-3
# Item []
# Id 26475672
# PubDate 2016 May 1
# EPubDate 2015 Sep 25
# Source Biol Psychiatry
# AuthorList ['Yoon G', 'Pittman B', 'Limoncelli D', 'Krystal JH', 'Petrakis IL']
# LastAuthor Petrakis IL
# Title Familial Alcoholism Risk and the Ratio of Stimulant to Sedative Effects of Ketamine.
# Volume 79
# Issue 9
# Pages e69-e70
# LangList ['English']
# NlmUniqueID 0213264
# ISSN 0006-3223
# ESSN 1873-2402
# PubTypeList ['Letter', 'Randomized Controlled Trial']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26475672'], 'medline': [], 'pii': 'S0006-3223(15)00766-0', 'doi': '10.1016/j.biopsych.2015.09.006', 'rid': '26475672', 'eid': '26475672'}
# DOI 10.1016/j.biopsych.2015.09.006
# History {'pubmed': ['2015/10/18 06:00'], 'medline': ['2016/12/31 06:00'], 'received': '2015/08/13 00:00', 'revised': '2015/09/16 00:00', 'accepted': '2015/09/16 00:00', 'entrez': '2015/10/18 06:00'}
# References []
# HasAbstract 0
# PmcRefCount 4
# FullJournalName Biological psychiatry
# ELocationID doi: 10.1016/j.biopsych.2015.09.006
# SO 2016 May 1;79(9):e69-e70
# Item []
# Id 26455281
# PubDate 2015 Dec
# EPubDate 2015 Oct 9
# Source Pharmacol Biochem Behav
# AuthorList ['Stankiewicz AM', 'Goscik J', 'Dyr W', 'Juszczak GR', 'Ryglewicz D', 'Swiergiel AH', 'Wieczorek M', 'Stefanski R']
# LastAuthor Stefanski R
# Title Novel candidate genes for alcoholism--transcriptomic analysis of prefrontal medial cortex, hippocampus and nucleus accumbens of Warsaw alcohol-preferring and non-preferring rats.
# Volume 139
# Issue Pt A
# Pages 27-38
# LangList ['English']
# NlmUniqueID 0367050
# ISSN 0091-3057
# ESSN 1873-5177
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26455281'], 'medline': [], 'pii': 'S0091-3057(15)30075-7', 'doi': '10.1016/j.pbb.2015.10.003', 'rid': '26455281', 'eid': '26455281'}
# DOI 10.1016/j.pbb.2015.10.003
# History {'pubmed': ['2015/10/13 06:00'], 'medline': ['2016/09/23 06:00'], 'received': '2015/05/13 00:00', 'revised': '2015/10/06 00:00', 'accepted': '2015/10/06 00:00', 'entrez': '2015/10/13 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Pharmacology, biochemistry, and behavior
# ELocationID doi: 10.1016/j.pbb.2015.10.003
# SO 2015 Dec;139(Pt A):27-38
# Item []
# Id 26452454
# PubDate 2016
# EPubDate 2015 Oct 9
# Source Health Commun
# AuthorList ['Haverfield MC', 'Theiss JA']
# LastAuthor Theiss JA
# Title Parent's alcoholism severity and family topic avoidance about alcohol as predictors of perceived stigma among adult children of alcoholics: Implications for emotional and psychological resilience.
# Volume 31
# Issue 5
# Pages 606-16
# LangList ['English']
# NlmUniqueID 8908762
# ISSN 1041-0236
# ESSN 1532-7027
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26452454'], 'medline': [], 'doi': '10.1080/10410236.2014.981665', 'rid': '26452454', 'eid': '26452454'}
# DOI 10.1080/10410236.2014.981665
# History {'pubmed': ['2015/10/11 06:00'], 'medline': ['2017/04/07 06:00'], 'entrez': '2015/10/11 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Health communication
# ELocationID doi: 10.1080/10410236.2014.981665
# SO 2016;31(5):606-16
# Item []
# Id 26437315
# PubDate 2015 Sep 29
# EPubDate 2015 Sep 29
# Source Adicciones
# AuthorList ['Serecigni JG']
# LastAuthor Serecigni JG
# Title Opioid Receptor Antagonists in the Treatment of Alcoholism.
# Volume 27
# Issue 3
# Pages 214-30
# LangList ['English', 'Spanish']
# NlmUniqueID 9605506
# ISSN 0214-4840
# ESSN
# PubTypeList ['Journal Article', 'Review']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26437315'], 'medline': [], 'rid': '26437315', 'eid': '26437315'}
# History {'pubmed': ['2015/10/06 06:00'], 'medline': ['2017/08/25 06:00'], 'entrez': '2015/10/06 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Adicciones
# ELocationID
# SO 2015 Sep 29;27(3):214-30
# Item []
# Id 26426670
# PubDate 2015 Sep
# EPubDate
# Source Medicine (Baltimore)
# AuthorList ['Tsai MH', 'Lin SH', 'Leu JG', 'Fang YW']
# LastAuthor Fang YW
# Title Hypokalemic Paralysis Complicated by Concurrent Hyperthyroidism and Chronic Alcoholism: A Case Report.
# Volume 94
# Issue 39
# Pages e1689
# LangList ['English']
# NlmUniqueID 2985248R
# ISSN 0025-7974
# ESSN 1536-5964
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26426670'], 'medline': [], 'doi': '10.1097/MD.0000000000001689', 'pii': '00005792-201509050-00070', 'pmc': 'PMC4616825', 'rid': '26426670', 'eid': '26426670', 'pmcid': 'pmc-id: PMC4616825;'}
# DOI 10.1097/MD.0000000000001689
# History {'pubmed': ['2015/10/02 06:00'], 'medline': ['2016/01/09 06:00'], 'entrez': '2015/10/02 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Medicine
# ELocationID doi: 10.1097/MD.0000000000001689
# SO 2015 Sep;94(39):e1689
# Item []
# Id 26418276
# PubDate 2015 Sep 29
# EPubDate 2015 Sep 29
# Source Transl Psychiatry
# AuthorList ['Wiers CE', 'Shumay E', 'Volkow ND', 'Frieling H', 'Kotsiari A', 'Lindenmeyer J', 'Walter H', 'Bermpohl F']
# LastAuthor Bermpohl F
# Title Effects of depressive symptoms and peripheral DAT methylation on neural reactivity to alcohol cues in alcoholism.
# Volume 5
# Issue
# Pages e648
# LangList ['English']
# NlmUniqueID 101562664
# ISSN
# ESSN 2158-3188
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26418276'], 'medline': [], 'pii': 'tp2015141', 'doi': '10.1038/tp.2015.141', 'pmc': 'PMC5545640', 'rid': '26418276', 'eid': '26418276', 'pmcid': 'pmc-id: PMC5545640;'}
# DOI 10.1038/tp.2015.141
# History {'pubmed': ['2015/09/30 06:00'], 'medline': ['2016/07/12 06:00'], 'received': '2015/04/19 00:00', 'revised': '2015/08/01 00:00', 'accepted': '2015/08/05 00:00', 'entrez': '2015/09/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 8
# FullJournalName Translational psychiatry
# ELocationID doi: 10.1038/tp.2015.141
# SO 2015 Sep 29;5:e648

# %% [markdown]
# This returns all the attributes for the most recent articles published in PubMed that include our keyword.  We can compile these attributes into a .csv file to make them easy to share.

# %%
#Compile attributes to a .csv file

# %%
import csv
csv_columns = ['Item','Id','PubDate', 'EPubDate', 'Source', 'AuthorList', 'LastAuthor', 'Title', 'Volume', 'Issue', 'Pages', 'LangList', 'NlmUniqueID', 'ISSN', 'ESSN', 'PubTypeList', 'RecordStatus', 'PubStatus', 'ArticleIds', 'DOI', 'History', 'References', 'HasAbstract', 'PmcRefCount', 'FullJournalName', 'ELocationID', 'SO']
dict_data = attributes_list
csv_file = "PubMed_Output.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for info in dict_data:
            for attribute_info in info:
                writer.writerow(attribute_info)
except IOError:
    print("I/O error")

# %% [markdown]
# After formatting the citation and putting it into a .csv file, we can to display the data as a bar graph of number of references for each of the articles.

# %%
#Format information into a citation

# %%
citation = defaultdict(list)

for cite in attributes_list: 
    for attribute_cite in cite:
        for key, value in attribute_cite.items():
            citation[key].append(value)

print(citation['LastAuthor'])
# Out:
# ['Pascual Pastor F', 'Varodayan F', 'Liu H', 'Pitel AL', 'Wan GR', 'Naegle M', 'Dabur R', 'Porjesz B', 'Desmond JE', 'Ben Hadj Ali B', 'Cservenka A', 'Sinha R', 'Choate PW', 'Nau JY', 'Petrakis IL', 'Stefanski R', 'Theiss JA', 'Serecigni JG', 'Fang YW', 'Bermpohl F']

# %%
#Produce bar graph from citation that counts number of references per author

# %%
attribute_data_plot = plt.barh(citation['LastAuthor'], citation['PmcRefCount'])
plt.ylabel = 'Number of References'
plt.xlabel = 'Author'
plt.title = 'Number of References by Author'
plt.show()

# %% [markdown]
# Alternatively, if you chose to search by author instead of title at the top, you can display a bar graph to see that author's most cited works.

# %%
#author_data  = plt.barh(citation['Title'], citation['PmcRefCount'])
#plt.ylabel = 'Number of References'
#plt.xlabel = 'Title'
#plt.title = "Most Cited Publications"
#plt.show()
