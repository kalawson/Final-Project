# %%
import pandas as pd
import matplotlib.pyplot as plt
from Bio import Entrez
import csv
from collections import defaultdict
import pytest

# %%
#run test using a different keyword - "lupus"

# %%
#Register with Entrez
Entrez.email = 'taylorlynstephan@gmail.com'

# %%
#Define keyword, area, and range of years that you want to search on PubMed
keyword = 'lupus'
area = 'Title'
start_year_range = '2005'
end_year_range = '2015'

# %%
#Use eSearch to return PMIDs about your topic
handle = Entrez.esearch(db='pubmed', term=keyword, field = area, retmode='xml', idtype='acc', mindate=start_year_range, maxdate=end_year_range)
data = Entrez.read(handle)

# %%
#Use eSummary to convert PMIDs to useful information
UID = data['IdList']
print(UID)
# Out:
# ['26714024', '26713607', '26713539', '26713507', '26713408', '26712669', '26712500', '26712498', '26711973', '26711923', '26711309', '26710814', '26710505', '26709643', '26709544', '26709090', '26705467', '26704903', '26703710', '26702344']

# %%
attributes_list = []

for ID in range(len(UID)):
    record = Entrez.esummary(db='pubmed', id=UID[ID])
    attributes_list.append(Entrez.read(record))

# %%
for attributes in attributes_list:
    for information in attributes:
        for key1, value1 in information.items():
            print(key1, value1)
# Out:
# Item []
# Id 26714024
# PubDate 2016 Sep
# EPubDate 2016 Jul 29
# Source Arthritis Care Res (Hoboken)
# AuthorList ['Medina-Rosas J', 'Yap KS', 'Anderson M', 'Su J', 'Touma Z']
# LastAuthor Touma Z
# Title Utility of Urinary Protein-Creatinine Ratio and Protein Content in a 24-Hour Urine Collection in Systemic Lupus Erythematosus: A Systematic Review and Meta-Analysis.
# Volume 68
# Issue 9
# Pages 1310-9
# LangList ['English']
# NlmUniqueID 101518086
# ISSN 2151-464X
# ESSN 2151-4658
# PubTypeList ['Journal Article', 'Meta-Analysis', 'Review']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26714024'], 'medline': [], 'doi': '10.1002/acr.22828', 'rid': '26714024', 'eid': '26714024'}
# DOI 10.1002/acr.22828
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/07/20 06:00'], 'received': '2015/09/16 00:00', 'revised': '2015/12/07 00:00', 'accepted': '2015/12/15 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 5
# FullJournalName Arthritis care & research
# ELocationID doi: 10.1002/acr.22828
# SO 2016 Sep;68(9):1310-9
# Item []
# Id 26713607
# PubDate 2016 May
# EPubDate 2016 Mar 25
# Source Br J Dermatol
# AuthorList ['Nakamura K', 'Jinnin M', 'Kudo H', 'Inoue K', 'Nakayama W', 'Honda N', 'Kajihara I', 'Masuguchi S', 'Fukushima S', 'Ihn H']
# LastAuthor Ihn H
# Title The role of PSMB9 upregulated by interferon signature in the pathophysiology of cutaneous lesions of dermatomyositis and systemic lupus erythematosus.
# Volume 174
# Issue 5
# Pages 1030-41
# LangList ['English']
# NlmUniqueID 0004041
# ISSN 0007-0963
# ESSN 1365-2133
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26713607'], 'medline': [], 'doi': '10.1111/bjd.14385', 'rid': '26713607', 'eid': '26713607'}
# DOI 10.1111/bjd.14385
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/03/23 06:00'], 'accepted': '2015/12/22 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName The British journal of dermatology
# ELocationID doi: 10.1111/bjd.14385
# SO 2016 May;174(5):1030-41
# Item []
# Id 26713539
# PubDate 2016 Apr
# EPubDate
# Source Arthritis Rheumatol
# AuthorList ['Reygaerts T', 'Arnaud L', 'Devilliers H']
# LastAuthor Devilliers H
# Title Survival Analysis Is Preferable to a Count of Events When Assessing the Effects of Tobacco Exposure in Systemic Lupus Erythematosus: Comment on the Article by Montes et al.
# Volume 68
# Issue 4
# Pages 1046-7
# LangList ['English']
# NlmUniqueID 101623795
# ISSN 2326-5191
# ESSN 2326-5205
# PubTypeList ['Comment', 'Letter']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26713539'], 'medline': [], 'doi': '10.1002/art.39552', 'rid': '26713539', 'eid': '26713539'}
# DOI 10.1002/art.39552
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/08/02 06:00'], 'received': '2015/10/07 00:00', 'accepted': '2015/12/10 00:00', 'entrez': '2015/12/30 06:00'}
# References ['Arthritis Rheumatol. 2016 Feb;68(2):441-8. PMID: 26359794']
# HasAbstract 0
# PmcRefCount 0
# FullJournalName Arthritis & rheumatology (Hoboken, N.J.)
# ELocationID doi: 10.1002/art.39552
# SO 2016 Apr;68(4):1046-7
# Item []
# Id 26713507
# PubDate 2016 May
# EPubDate
# Source Arthritis Rheumatol
# AuthorList ['Liu K', 'Kurien BT', 'Zimmerman SL', 'Kaufman KM', 'Taft DH', 'Kottyan LC', 'Lazaro S', 'Weaver CA', 'Ice JA', 'Adler AJ', 'Chodosh J', 'Radfar L', 'Rasmussen A', 'Stone DU', 'Lewis DM', 'Li S', 'Koelsch KA', 'Igoe A', 'Talsania M', 'Kumar J', 'Maier-Moore JS', 'Harris VM', 'Gopalakrishnan R', 'Jonsson R', 'Lessard JA', 'Lu X', 'Gottenberg JE', 'Anaya JM', 'Cunninghame-Graham DS', 'Huang AJW', 'Brennan MT', 'Hughes P', 'Illei GG', 'Miceli-Richard C', 'Keystone EC', 'Bykerk VP', 'Hirschfield G', 'Xie G', 'Ng WF', 'Nordmark G', 'Eriksson P', 'Omdal R', 'Rhodus NL', 'Rischmueller M', 'Rohrer M', 'Segal BM', 'Vyse TJ', 'Wahren-Herlenius M', 'Witte T', 'Pons-Estel B', 'Alarcon-Riquelme ME', 'Guthridge JM', 'James JA', 'Lessard CJ', 'Kelly JA', 'Thompson SD', 'Gaffney PM', 'Montgomery CG', 'Edberg JC', 'Kimberly RP', 'Alarcón GS', 'Langefeld CL', 'Gilkeson GS', 'Kamen DL', 'Tsao BP', 'McCune WJ', 'Salmon JE', 'Merrill JT', 'Weisman MH', 'Wallace DJ', 'Utset TO', 'Bottinger EP', 'Amos CI', 'Siminovitch KA', 'Mariette X', 'Sivils KL', 'Harley JB', 'Scofield RH']
# LastAuthor Scofield RH
# Title X Chromosome Dose and Sex Bias in Autoimmune Diseases: Increased Prevalence of 47,XXX in Systemic Lupus Erythematosus and Sjögren's Syndrome.
# Volume 68
# Issue 5
# Pages 1290-1300
# LangList ['English']
# NlmUniqueID 101623795
# ISSN 2326-5191
# ESSN 2326-5205
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26713507'], 'medline': [], 'doi': '10.1002/art.39560', 'pmc': 'PMC5019501', 'mid': 'NIHMS809756', 'rid': '26713507', 'eid': '26713507', 'pmcid': 'pmc-id: PMC5019501;manuscript-id: NIHMS809756;'}
# DOI 10.1002/art.39560
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/07/08 06:00'], 'received': '2015/01/04 00:00', 'accepted': '2015/12/15 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 18
# FullJournalName Arthritis & rheumatology (Hoboken, N.J.)
# ELocationID doi: 10.1002/art.39560
# SO 2016 May;68(5):1290-1300
# Item []
# Id 26713408
# PubDate 2016 May
# EPubDate
# Source Arthritis Rheumatol
# AuthorList ['Fleischer SJ', 'Daridon C', 'Fleischer V', 'Lipsky PE', 'Dörner T']
# LastAuthor Dörner T
# Title Enhanced Tyrosine Phosphatase Activity Underlies Dysregulated B Cell Receptor Signaling and Promotes Survival of Human Lupus B Cells.
# Volume 68
# Issue 5
# Pages 1210-21
# LangList ['English']
# NlmUniqueID 101623795
# ISSN 2326-5191
# ESSN 2326-5205
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26713408'], 'medline': [], 'doi': '10.1002/art.39559', 'rid': '26713408', 'eid': '26713408'}
# DOI 10.1002/art.39559
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/07/08 06:00'], 'received': '2015/06/09 00:00', 'accepted': '2015/12/08 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 6
# FullJournalName Arthritis & rheumatology (Hoboken, N.J.)
# ELocationID doi: 10.1002/art.39559
# SO 2016 May;68(5):1210-21
# Item []
# Id 26712669
# PubDate 2015 Dec
# EPubDate
# Source Malays J Pathol
# AuthorList ['Chow TK', 'Looi LM', 'Cheah PL']
# LastAuthor Cheah PL
# Title A comparison of 1995 WHO classification with 2003 ISN/RPS classification of lupus nephritis: a single centre observation.
# Volume 37
# Issue 3
# Pages 239-46
# LangList ['English']
# NlmUniqueID 8101177
# ISSN 0126-8635
# ESSN
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26712669'], 'medline': [], 'rid': '26712669', 'eid': '26712669'}
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/03/02 06:00'], 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName The Malaysian journal of pathology
# ELocationID
# SO 2015 Dec;37(3):239-46
# Item []
# Id 26712500
# PubDate 2016 Jun
# EPubDate 2015 Dec 28
# Source Clin Rheumatol
# AuthorList ['De Scheerder MA', 'Boey O', 'Mahieu E', 'Vanuytsel J', 'Bogaert AM']
# LastAuthor Bogaert AM
# Title Case report: successful treatment of membranous lupus nephritis with belimumab in an African female immigrant.
# Volume 35
# Issue 6
# Pages 1649-53
# LangList ['English']
# NlmUniqueID 8211469
# ISSN 0770-3198
# ESSN 1434-9949
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26712500'], 'medline': [], 'doi': '10.1007/s10067-015-3153-1', 'pii': '10.1007/s10067-015-3153-1', 'rid': '26712500', 'eid': '26712500'}
# DOI 10.1007/s10067-015-3153-1
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/03/16 06:00'], 'received': '2015/08/10 00:00', 'accepted': '2015/12/15 00:00', 'revised': '2015/12/13 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Clinical rheumatology
# ELocationID doi: 10.1007/s10067-015-3153-1
# SO 2016 Jun;35(6):1649-53
# Item []
# Id 26712498
# PubDate 2016 Apr
# EPubDate 2015 Dec 28
# Source Clin Rheumatol
# AuthorList ['Hu W', 'Niu G', 'Lin Y', 'Chen X', 'Lin L']
# LastAuthor Lin L
# Title Impact of the polymorphism in vitamin D receptor gene BsmI and the risk of systemic lupus erythematosus: an updated meta-analysis.
# Volume 35
# Issue 4
# Pages 927-34
# LangList ['English']
# NlmUniqueID 8211469
# ISSN 0770-3198
# ESSN 1434-9949
# PubTypeList ['Journal Article', 'Meta-Analysis']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26712498'], 'medline': [], 'doi': '10.1007/s10067-015-3157-x', 'pii': '10.1007/s10067-015-3157-x', 'rid': '26712498', 'eid': '26712498'}
# DOI 10.1007/s10067-015-3157-x
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/01/17 06:00'], 'received': '2015/10/04 00:00', 'accepted': '2015/12/20 00:00', 'revised': '2015/11/28 00:00', 'entrez': '2015/12/30 06:00'}
# References ['Clin Rheumatol. 2016 Apr;35(4):1121. PMID: 26861033']
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Clinical rheumatology
# ELocationID doi: 10.1007/s10067-015-3157-x
# SO 2016 Apr;35(4):927-34
# Item []
# Id 26711973
# PubDate 2015 Sep 8
# EPubDate
# Source Zhonghua Yi Xue Za Zhi
# AuthorList ['Shou W', 'Chen Q', 'Wu W', 'Fan L', 'Xie T', 'Cui W']
# LastAuthor Cui W
# Title [Research of the efficiency of different lupus anticoagulant assays].
# Volume 95
# Issue 34
# Pages 2760-5
# LangList ['Chinese']
# NlmUniqueID 7511141
# ISSN 0376-2491
# ESSN
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26711973'], 'medline': [], 'rid': '26711973', 'eid': '26711973'}
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/03/31 06:00'], 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Zhonghua yi xue za zhi
# ELocationID
# SO 2015 Sep 8;95(34):2760-5
# Item []
# Id 26711923
# PubDate 2015 Dec
# EPubDate
# Source Pediatr Int
# AuthorList ['Shimozawa H', 'Kono Y', 'Matano M', 'Suzuki Y', 'Koike Y', 'Yada Y', 'Yamagata T', 'Takahashi N']
# LastAuthor Takahashi N
# Title Cytokine profile in two siblings with neonatal lupus erythematosus.
# Volume 57
# Issue 6
# Pages 1211-4
# LangList ['English']
# NlmUniqueID 100886002
# ISSN 1328-8067
# ESSN 1442-200X
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26711923'], 'medline': [], 'doi': '10.1111/ped.12723', 'rid': '26711923', 'eid': '26711923'}
# DOI 10.1111/ped.12723
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2017/01/18 06:00'], 'received': '2015/02/16 00:00', 'revised': '2015/05/13 00:00', 'accepted': '2015/05/20 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Pediatrics international : official journal of the Japan Pediatric Society
# ELocationID doi: 10.1111/ped.12723
# SO 2015 Dec;57(6):1211-4
# Item []
# Id 26711309
# PubDate 2016 Apr
# EPubDate 2015 Oct 29
# Source Semin Arthritis Rheum
# AuthorList ['Tselios K', 'Koumaras C', 'Gladman DD', 'Urowitz MB']
# LastAuthor Urowitz MB
# Title Dyslipidemia in systemic lupus erythematosus: just another comorbidity?
# Volume 45
# Issue 5
# Pages 604-10
# LangList ['English']
# NlmUniqueID 1306053
# ISSN 0049-0172
# ESSN 1532-866X
# PubTypeList ['Journal Article', 'Review']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26711309'], 'medline': [], 'pii': 'S0049-0172(15)00271-1', 'doi': '10.1016/j.semarthrit.2015.10.010', 'rid': '26711309', 'eid': '26711309'}
# DOI 10.1016/j.semarthrit.2015.10.010
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/12/31 06:00'], 'received': '2015/06/29 00:00', 'revised': '2015/10/13 00:00', 'accepted': '2015/10/23 00:00', 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 12
# FullJournalName Seminars in arthritis and rheumatism
# ELocationID doi: 10.1016/j.semarthrit.2015.10.010
# SO 2016 Apr;45(5):604-10
# Item []
# Id 26710814
# PubDate 2015 Jul 7
# EPubDate
# Source Zhonghua Yi Xue Za Zhi
# AuthorList ['Li C', 'Li S', 'Zhang J', 'Tan X', 'Li Y', 'Li C', 'Deng J', 'Yan X']
# LastAuthor Yan X
# Title [Role of glomerular mesangial cell in the pathogenetic progress of lupus nephritis fibrosis].
# Volume 95
# Issue 25
# Pages 2018-21
# LangList ['Chinese']
# NlmUniqueID 7511141
# ISSN 0376-2491
# ESSN
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26710814'], 'medline': [], 'rid': '26710814', 'eid': '26710814'}
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/03/25 06:00'], 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Zhonghua yi xue za zhi
# ELocationID
# SO 2015 Jul 7;95(25):2018-21
# Item []
# Id 26710505
# PubDate 2015 Jul-Sep
# EPubDate
# Source Rom J Intern Med
# AuthorList ['Ozaslan E', 'Eroglu E', 'Gok K', 'Senel S', 'Baldane S', 'Akyol L', 'Ozkan M']
# LastAuthor Ozkan M
# Title Drug Induced Lupus Erythematosus Due to Capecitabine and Bevacizumab Treatment Presenting with Prolonged Thrombocytopenia.
# Volume 53
# Issue 3
# Pages 282-5
# LangList ['English']
# NlmUniqueID 9304507
# ISSN 1220-4749
# ESSN 2501-062X
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish
# ArticleIds {'pubmed': ['26710505'], 'medline': [], 'doi': '10.1515/rjim-2015-0037', 'rid': '26710505', 'eid': '26710505'}
# DOI 10.1515/rjim-2015-0037
# History {'pubmed': ['2015/12/30 06:00'], 'medline': ['2016/02/02 06:00'], 'entrez': '2015/12/30 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Romanian journal of internal medicine = Revue roumaine de medecine interne
# ELocationID
# SO 2015 Jul-Sep;53(3):282-5
# Item []
# Id 26709643
# PubDate 2016 Jan 1
# EPubDate 2016 Jan 1
# Source Front Biosci (Elite Ed)
# AuthorList ['Chung KT']
# LastAuthor Chung KT
# Title Carcinogenicity, allergenicity, and lupus-inducibility of arylamines.
# Volume 8
# Issue
# Pages 29-39
# LangList ['English']
# NlmUniqueID 101485240
# ISSN 1945-0494
# ESSN 1945-0508
# PubTypeList ['Journal Article', 'Review']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26709643'], 'medline': [], 'pii': '748', 'rid': '26709643', 'eid': '26709643'}
# History {'pubmed': ['2015/12/29 06:00'], 'medline': ['2016/09/27 06:00'], 'entrez': '2015/12/29 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Frontiers in bioscience (Elite edition)
# ELocationID
# SO 2016 Jan 1;8:29-39
# Item []
# Id 26709544
# PubDate 2016 Nov
# EPubDate 2015 Dec 28
# Source Mitochondrial DNA A DNA Mapp Seq Anal
# AuthorList ['Guo X', 'Pei J', 'Bao P', 'Yan P', 'Lu D']
# LastAuthor Lu D
# Title The complete mitochondrial genome of Hequ Tibetan Mastiff Canis lupus familiaris (Carnivora: Canidae).
# Volume 27
# Issue 6
# Pages 4659-4660
# LangList ['English']
# NlmUniqueID 101679980
# ISSN 2470-1394
# ESSN 2470-1408
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26709544'], 'medline': [], 'doi': '10.3109/19401736.2015.1106490', 'rid': '26709544', 'eid': '26709544'}
# DOI 10.3109/19401736.2015.1106490
# History {'pubmed': ['2015/12/29 06:00'], 'medline': ['2018/02/06 06:00'], 'entrez': '2015/12/29 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 0
# FullJournalName Mitochondrial DNA. Part A, DNA mapping, sequencing, and analysis
# ELocationID
# SO 2016 Nov;27(6):4659-4660
# Item []
# Id 26709090
# PubDate 2016 Nov - Dec
# EPubDate 2015 Dec 18
# Source Semergen
# AuthorList ['Recarey-Mayo A', 'Hermida-Ameijeiras A', 'López-Paz JE', 'Calvo-Gómez C']
# LastAuthor Calvo-Gómez C
# Title [Thiazide diuretics induce subacute cutaneous lupus erythematosus].
# Volume 42
# Issue 8
# Pages e174-e176
# LangList ['Spanish']
# NlmUniqueID 9610769
# ISSN 1138-3593
# ESSN 1578-8865
# PubTypeList ['Letter']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26709090'], 'medline': [], 'pii': 'S1138-3593(15)00391-3', 'doi': '10.1016/j.semerg.2015.10.017', 'rid': '26709090', 'eid': '26709090'}
# DOI 10.1016/j.semerg.2015.10.017
# History {'pubmed': ['2015/12/29 06:00'], 'medline': ['2017/05/26 06:00'], 'received': '2015/10/02 00:00', 'revised': '2015/10/13 00:00', 'accepted': '2015/10/22 00:00', 'entrez': '2015/12/29 06:00'}
# References []
# HasAbstract 0
# PmcRefCount 0
# FullJournalName Semergen
# ELocationID doi: 10.1016/j.semerg.2015.10.017
# SO 2016 Nov - Dec;42(8):e174-e176
# Item []
# Id 26705467
# PubDate 2015
# EPubDate 2015 Dec 23
# Source Cell Biosci
# AuthorList ['Cheng HB', 'Chen RY', 'Wu JP', 'Chen L', 'Liang YH', 'Pan HF', 'Pan ZF', 'Zhang QH', 'Li Q', 'Du TX', 'Lv YM', 'Shi JQ']
# LastAuthor Shi JQ
# Title Complement C4 induces regulatory T cells differentiation through dendritic cell in systemic lupus erythematosus.
# Volume 5
# Issue
# Pages 73
# LangList ['English']
# NlmUniqueID 101561195
# ISSN
# ESSN 2045-3701
# PubTypeList ['Journal Article']
# RecordStatus PubMed
# PubStatus
# ArticleIds {'pubmed': ['26705467'], 'medline': [], 'doi': '10.1186/s13578-015-0052-8', 'pii': '52', 'pmc': 'PMC4690337', 'rid': '26705467', 'eid': '26705467', 'pmcid': 'pmc-id: PMC4690337;'}
# DOI 10.1186/s13578-015-0052-8
# History {'pubmed': ['2015/12/26 06:00'], 'medline': ['2015/12/26 06:01'], 'received': '2015/08/10 00:00', 'accepted': '2015/10/28 00:00', 'entrez': '2015/12/26 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Cell & bioscience
# ELocationID doi: 10.1186/s13578-015-0052-8
# SO 2015;5:73
# Item []
# Id 26704903
# PubDate 2015 Dec 24
# EPubDate 2015 Dec 24
# Source Arthritis Res Ther
# AuthorList ['Pesickova SS', 'Rysava R', 'Lenicek M', 'Vitek L', 'Potlukova E', 'Hruskova Z', 'Jancova E', 'Honsova E', 'Zavada J', 'Trendelenburg M', 'Tesar V']
# LastAuthor Tesar V
# Title Prognostic value of anti-CRP antibodies in lupus nephritis in long-term follow-up.
# Volume 17
# Issue
# Pages 371
# LangList ['English']
# NlmUniqueID 101154438
# ISSN 1478-6354
# ESSN 1478-6362
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26704903'], 'medline': [], 'doi': '10.1186/s13075-015-0879-8', 'pii': '10.1186/s13075-015-0879-8', 'pmc': 'PMC4718018', 'rid': '26704903', 'eid': '26704903', 'pmcid': 'pmc-id: PMC4718018;'}
# DOI 10.1186/s13075-015-0879-8
# History {'pubmed': ['2015/12/26 06:00'], 'medline': ['2016/09/08 06:00'], 'received': '2015/09/19 00:00', 'accepted': '2015/11/27 00:00', 'entrez': '2015/12/26 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 2
# FullJournalName Arthritis research & therapy
# ELocationID doi: 10.1186/s13075-015-0879-8
# SO 2015 Dec 24;17:371
# Item []
# Id 26703710
# PubDate 2015 Dec 23
# EPubDate 2015 Dec 23
# Source Int J Environ Res Public Health
# AuthorList ['Crowe W', 'Doherty L', 'Watson G', 'Armstrong D', 'Ball E', 'Magee P', 'Allsopp P', 'Bell A', 'Strain JJ', 'McSorley E']
# LastAuthor McSorley E
# Title Mercury in Hair Is Inversely Related to Disease Associated Damage in Systemic Lupus Erythematosus.
# Volume 13
# Issue 1
# Pages ijerph13010075
# LangList ['English']
# NlmUniqueID 101238455
# ISSN 1661-7827
# ESSN 1660-4601
# PubTypeList ['Journal Article']
# RecordStatus PubMed - indexed for MEDLINE
# PubStatus epublish
# ArticleIds {'pubmed': ['26703710'], 'medline': [], 'pii': 'ijerph13010075', 'doi': '10.3390/ijerph13010075', 'pmc': 'PMC4730466', 'rid': '26703710', 'eid': '26703710', 'pmcid': 'pmc-id: PMC4730466;'}
# DOI 10.3390/ijerph13010075
# History {'pubmed': ['2015/12/26 06:00'], 'medline': ['2016/08/04 06:00'], 'received': '2015/11/01 00:00', 'revised': '2015/12/02 00:00', 'accepted': '2015/12/14 00:00', 'entrez': '2015/12/26 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName International journal of environmental research and public health
# ELocationID doi: 10.3390/ijerph13010075
# SO 2015 Dec 23;13(1):ijerph13010075
# Item []
# Id 26702344
# PubDate 2015
# EPubDate 2015 Nov 26
# Source J Cardiovasc Thorac Res
# AuthorList ['Acar RD', 'Bulut M', 'Acar Ş', 'Izci S', 'Fidan S', 'Yesin M', 'Efe SC']
# LastAuthor Efe SC
# Title Evaluation of the P Wave Axis in Patients With Systemic Lupus Erythematosus.
# Volume 7
# Issue 4
# Pages 154-7
# LangList ['English']
# NlmUniqueID 101528712
# ISSN 2008-5117
# ESSN 2008-6830
# PubTypeList ['Journal Article']
# RecordStatus PubMed
# PubStatus ppublish+epublish
# ArticleIds {'pubmed': ['26702344'], 'medline': [], 'doi': '10.15171/jcvtr.2015.33', 'pmc': 'PMC4685281', 'rid': '26702344', 'eid': '26702344', 'pmcid': 'pmc-id: PMC4685281;'}
# DOI 10.15171/jcvtr.2015.33
# History {'pubmed': ['2015/12/25 06:00'], 'medline': ['2015/12/25 06:01'], 'received': '2015/06/22 00:00', 'accepted': '2015/11/23 00:00', 'entrez': '2015/12/25 06:00'}
# References []
# HasAbstract 1
# PmcRefCount 1
# FullJournalName Journal of cardiovascular and thoracic research
# ELocationID doi: 10.15171/jcvtr.2015.33
# SO 2015;7(4):154-7

# %%
#Compile attributes to a .csv file
import csv
csv_columns = ['Item','Id','PubDate', 'EPubDate', 'Source', 'AuthorList', 'LastAuthor', 'Title', 'Volume', 'Issue', 'Pages', 'LangList', 'NlmUniqueID', 'ISSN', 'ESSN', 'PubTypeList', 'RecordStatus', 'PubStatus', 'ArticleIds', 'DOI', 'History', 'References', 'HasAbstract', 'PmcRefCount', 'FullJournalName', 'ELocationID', 'SO']
dict_data = attributes_list
csv_file = "PubMed_Output.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for info in dict_data:
            for attribute_info in info:
                writer.writerow(attribute_info)
except IOError:
    print("I/O error")

# %%
#Format information into a citation
citation = defaultdict(list)

for cite in attributes_list: 
    for attribute_cite in cite:
        for key, value in attribute_cite.items():
            citation[key].append(value)

print(citation['LastAuthor'])
# Out:
# ['Touma Z', 'Ihn H', 'Devilliers H', 'Scofield RH', 'Dörner T', 'Cheah PL', 'Bogaert AM', 'Lin L', 'Cui W', 'Takahashi N', 'Urowitz MB', 'Yan X', 'Ozkan M', 'Chung KT', 'Lu D', 'Calvo-Gómez C', 'Shi JQ', 'Tesar V', 'McSorley E', 'Efe SC']

# %%
#Produce bar graph from citation that counts number of references per author
attribute_data_plot = plt.barh(citation['LastAuthor'], citation['PmcRefCount'])
plt.ylabel = 'Number of References'
plt.xlabel = 'Author'
plt.title = 'Number of References by Author'
plt.show()
